# %% [markdown]
# <a href="https://colab.research.google.com/github/AntonioCarbajalQuiroz/AntonioCarbajalQuiroz/blob/main/My_first_Collab_google.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


print(str(cv2.__version__))

print ("Hello word")
# Out:
# 4.11.0
# Hello word

# %%
# !pip install opencv-contrib-python

# %%
# %%bash
# ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# pip install gputil
# pip install psutil
# pip install humanize

# %%
import psutil
import humanize
import os
import GPUtil as GPU

GPUs = GPU.getGPUs()
gpu = GPUs[0]
print(len(GPUs))
# Out:
# 1

# %%
print("""GPU RAM Free: {0:.0f}MB \n Used_{1:.0f}MB \nUtil: {2:3.0f}% \n Total {3:.0f}MB""".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
# Out:
# GPU RAM Free: 15095MB
#  Used_0MB
# Util:   0%
#  Total 15360MB

# %%
print("Gen RAM Free:" + humanize.naturalsize(psutil.virtual_memory().available))
# Out:
# Gen RAM Free:12.1 GB

# %%
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         113G   37G   76G  33% /
# tmpfs            64M     0   64M   0% /dev
# shm             5.7G     0  5.7G   0% /dev/shm
# /dev/root       2.0G  1.2G  775M  61% /usr/sbin/docker-init
# tmpfs           6.4G  8.2M  6.4G   1% /var/colab
# /dev/sda1        92G   67G   25G  73% /kaggle/input
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware
